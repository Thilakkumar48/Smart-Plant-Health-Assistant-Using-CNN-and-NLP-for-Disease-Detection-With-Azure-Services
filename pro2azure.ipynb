# %%
import requests
import json

# Set up the endpoint, key, and the image you want to classify
prediction_key = "ca681d30-1b6f-4c1d-a387-68ce7ea94efe"
endpoint = "hhttps://p2leafdisease.cognitiveservices.azure.com/"
project_id = "ca681d30-1b6f-4c1d-a387-68ce7ea94efe"
publish_iteration_name = "Iteration2"
image_path = r"C:\Users\DELL\OneDrive\Desktop\Revature\P1\plantvillage dataset\color\Apple___Apple_scab\0a5e9323-dbad-432d-ac58-d291718345d9___FREC_Scab 3417.JPG"  # Use raw string
# Read the image file
with open(image_path, "rb") as image_file:
    image_data = image_file.read()

# Define headers and URL for prediction
headers = {
    'Prediction-Key': prediction_key,
    'Content-Type': 'application/octet-stream'
}
url = f"{endpoint}customvision/v3.0/Prediction/{project_id}/classify/iterations/{publish_iteration_name}/image"

# Make the prediction
response = requests.post(url, headers=headers, data=image_data)
result = response.json()
print(json.dumps(result, indent=2))
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Cell In[1], line 22
#      19 url = f"{endpoint}customvision/v3.0/Prediction/{project_id}/classify/iterations/{publish_iteration_name}/image"
#      21 # Make the prediction
# ---> 22 response = requests.post(url, headers=headers, data=image_data)
#      23 result = response.json()
#      24 print(json.dumps(result, indent=2))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# ...

# %%
pip install azure-storage-blob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import json
import uuid

# Prediction result from your plant disease model
prediction_result = "Apple Scab detected on the plant."

# Set up Azure Translator API credentials
subscription_key = 'd71d5ad9793c494ba91af058942f73df'  # Replace with your Azure Translator subscription key
endpoint = 'https://api.cognitive.microsofttranslator.com/'  # Translator API endpoint
location = 'eastus'  # The region your resource is in

# Specify the target language (e.g., 'es' for Spanish, 'fr' for French)
target_language = 'es'

# Set up the request URL and parameters
path = '/translate?api-version=3.0'
params = f'&to={target_language}'
constructed_url = endpoint + path + params

# Define the request headers
headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# Define the request body with the prediction result as text to translate
body = [{
    'text': prediction_result
}]

# Make the API request to translate the text
response = requests.post(constructed_url, headers=headers, json=body)

# Parse the API response
result = response.json()

# Extract the translated text
translated_text = result[0]['translations'][0]['text']

# Display the original and translated prediction
print(f"Original Prediction: {prediction_result}")
print(f"Translated Prediction: {translated_text}")
# Out:
# Original Prediction: Apple Scab detected on the plant.
# Translated Prediction: Se ha detectado sarna de manzana en la planta.

# %%
pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import openai
print("OpenAI library imported successfully!")
# Out:
# OpenAI library imported successfully!

# %%
import os
import openai
import requests

# Azure OpenAI settings
api_key = "61ad35e6fa9d46759ae53e5b4b02f354"
endpoint = "https://smartplantopenai.openai.azure.com/"
deployment_name = "openaigpt35turbo"  # Name of the deployed model

headers = {
    "Content-Type": "application/json",
    "api-key": api_key,
}

def generate_disease_suggestion(prompt):
    data = {
        "prompt": prompt,
        "max_tokens": 150,
        "temperature": 0.7,
        "top_p": 0.9,
        "n": 1,
        "stop": None
    }

    response = requests.post(f"{endpoint}/openai/deployments/{deployment_name}/completions?api-version=2023-03-15-preview", headers=headers, json=data)
    if response.status_code == 200:
        result = response.json()
        return result["choices"][0]["text"].strip()
    else:
        return f"Error: {response.status_code}, {response.text}"

# Example prompt
# plant_symptoms = "The plant leaves have yellow spots and are wilting."
plant_symptoms = "potato early blight"
prompt = f"Generate a possible diagnosis for the following plant symptoms: {plant_symptoms}"

disease_suggestion = generate_disease_suggestion(prompt)
print("Generated Disease Diagnosis:", disease_suggestion)
# Out:
# Generated Disease Diagnosis: A: Alternaria solani
#
# Q: What is the most common way to spread potato late blight?
# A: Wind
#
# Q: What is the most common way to spread potato early blight?
# A: Rain
#
# Q: What is the most common way to spread bacterial wilt in cucurbits?
# A: Insects
#
# Q: What is the most common way to spread downy mildew in cucurbits?
# A: Wind
#
# Q: What is the most common way to spread powdery mildew in cucurbits?
# A: Airborne spores
#
# Q: What is the most common way to spread squash mosaic virus in cucurbits?
# A: Aphids
#
# Q: What is the most common way to

# %%
import azure.cognitiveservices.speech as speechsdk

# Set up your Azure Speech Service subscription info
speech_key = "2d8ecb53901f475684918912bb47172e"  # Replace with your Azure Speech API key
service_region = "eastus"  # Replace with your Azure Speech service region

# Function to convert text to speech
def text_to_speech(text):
    # Create the configuration for the Azure Speech Service
    speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=service_region)
    audio_config = speechsdk.audio.AudioOutputConfig(use_default_speaker=True)

    # Create a speech synthesizer
    synthesizer = speechsdk.SpeechSynthesizer(speech_config=speech_config, audio_config=audio_config)

    # Convert the text to speech
    synthesizer.speak_text_async(text)

# Example usage: converting text into speech
text = "Your plant is diagnosed with a possible fungal infection. Immediate treatment is recommended."
text_to_speech(text)

# %%
import requests
import json
import uuid
import azure.cognitiveservices.speech as speechsdk

# Function to translate text using Azure Translator API
def translate_text(text, target_language='es'):
    subscription_key = 'd71d5ad9793c494ba91af058942f73df'  # Replace with your Azure Translator subscription key
    endpoint = 'https://api.cognitive.microsofttranslator.com/'  # Translator API endpoint
    location = 'eastus'  # The region your resource is in

    path = '/translate?api-version=3.0'
    params = f'&to={target_language}'
    constructed_url = endpoint + path + params

    headers = {
        'Ocp-Apim-Subscription-Key': subscription_key,
        'Ocp-Apim-Subscription-Region': location,
        'Content-type': 'application/json',
        'X-ClientTraceId': str(uuid.uuid4())
    }

    body = [{
        'text': text
    }]

    # Make the API request to translate the text
    response = requests.post(constructed_url, headers=headers, json=body)
    result = response.json()

    # Extract the translated text
    translated_text = result[0]['translations'][0]['text']
    return translated_text

# Function to convert text to speech using Azure Speech Service
def text_to_speech(text):
    speech_key = "2d8ecb53901f475684918912bb47172e"  # Replace with your Azure Speech API key
    service_region = "eastus"  # Replace with your Azure Speech service region

    speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=service_region)
    audio_config = speechsdk.audio.AudioOutputConfig(use_default_speaker=True)

    # Create a speech synthesizer
    synthesizer = speechsdk.SpeechSynthesizer(speech_config=speech_config, audio_config=audio_config)

    # Convert the text to speech
    synthesizer.speak_text_async(text)

# Integrated process: Translate and then Speak
def translate_and_speak(prediction, target_language='es'):
    # Translate the prediction result
    translated_text = translate_text(prediction, target_language)
    
    # Output the original and translated text
    print(f"Original Prediction: {prediction}")
    print(f"Translated Prediction: {translated_text}")
    
    # Convert the translated text to speech
    text_to_speech(translated_text)

# Example usage
prediction_result = "Apple Scab detected on the plant."
translate_and_speak(prediction_result, target_language='es')
# Out:
# Original Prediction: Apple Scab detected on the plant.
# Translated Prediction: Se ha detectado sarna de manzana en la planta.

# %%
import requests
import json
import uuid
import azure.cognitiveservices.speech as speechsdk

# Function to translate text using Azure Translator API
def translate_text(text, target_languages):
    subscription_key = 'd71d5ad9793c494ba91af058942f73df'  # Replace with your Azure Translator subscription key
    endpoint = 'https://api.cognitive.microsofttranslator.com/'  # Translator API endpoint
    location = 'eastus'  # The region your resource is in

    path = '/translate?api-version=3.0'
    params = f'&to={",".join(target_languages)}'  # Translate to multiple languages
    constructed_url = endpoint + path + params

    headers = {
        'Ocp-Apim-Subscription-Key': subscription_key,
        'Ocp-Apim-Subscription-Region': location,
        'Content-type': 'application/json',
        'X-ClientTraceId': str(uuid.uuid4())
    }

    body = [{
        'text': text
    }]

    # Make the API request to translate the text
    response = requests.post(constructed_url, headers=headers, json=body)
    result = response.json()

    # Extract the translations for each language
    translations = {translation['to']: translation['text'] for translation in result[0]['translations']}
    return translations

# Function to convert text to speech using Azure Speech Service
def text_to_speech(text, language):
    speech_key = "2d8ecb53901f475684918912bb47172e"  # Replace with your Azure Speech API key
    service_region = "eastus"  # Replace with your Azure Speech service region

    # Set up speech configuration for the specific language
    speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=service_region)
    speech_config.speech_synthesis_language = language  # Set the language for speech synthesis
    audio_config = speechsdk.audio.AudioOutputConfig(use_default_speaker=True)

    # Create a speech synthesizer
    synthesizer = speechsdk.SpeechSynthesizer(speech_config=speech_config, audio_config=audio_config)

    # Convert the text to speech
    synthesizer.speak_text_async(text)

# Integrated process: Translate and then Speak for multiple languages
def translate_and_speak(prediction, languages):
    # Map languages to Azure's speech synthesis language codes
    language_map = {
        'es': 'es-ES',  # Spanish
        'fr': 'fr-FR',  # French
        'te': 'te-IN',  # Telugu
        'hi': 'hi-IN',  # Hindi
        'de': 'de-DE'   # German
    }

    # Translate the prediction result
    translations = translate_text(prediction, languages)

    # Output the original prediction and translated predictions
    print(f"Original Prediction: {prediction}")
    for lang, translated_text in translations.items():
        print(f"Translated Prediction in {lang.upper()}: {translated_text}")
        
        # Convert the translated text to speech
        text_to_speech(translated_text, language_map[lang])

# Example usage
prediction_result = "Apple Scab detected on the plant."
languages = ['es', 'fr', 'te', 'hi', 'de']  # Spanish, French, Telugu, Hindi, German
translate_and_speak(prediction_result, languages)
# Out:
# Original Prediction: Apple Scab detected on the plant.
# Translated Prediction in ES: Se ha detectado sarna de manzana en la planta.
# Translated Prediction in FR: Tavelure du pommier détectée sur la plante.
# Translated Prediction in TE: ప్లాంట్ పై ఆపిల్ స్కాబ్ ను గుర్తించారు.
# Translated Prediction in HI: पौधे पर एप्पल स्कैब का पता चला।
# Translated Prediction in DE: Apfelschorf an der Pflanze nachgewiesen.

# %%
import requests
import json
import uuid
import azure.cognitiveservices.speech as speechsdk

# Function to translate text using Azure Translator API
def translate_text(text, target_languages):
    subscription_key = 'd71d5ad9793c494ba91af058942f73df'  # Replace with your Azure Translator subscription key
    endpoint = 'https://api.cognitive.microsofttranslator.com/'  # Translator API endpoint
    location = 'eastus'  # The region your resource is in

    path = '/translate?api-version=3.0'
    params = f'&to={",".join(target_languages)}'  # Translate to multiple languages
    constructed_url = endpoint + path + params

    headers = {
        'Ocp-Apim-Subscription-Key': subscription_key,
        'Ocp-Apim-Subscription-Region': location,
        'Content-type': 'application/json',
        'X-ClientTraceId': str(uuid.uuid4())
    }

    body = [{
        'text': text
    }]

    # Make the API request to translate the text
    response = requests.post(constructed_url, headers=headers, json=body)
    result = response.json()

    # Extract the translations for each language
    translations = {translation['to']: translation['text'] for translation in result[0]['translations']}
    return translations

# Function to convert text to speech using Azure Speech Service (synchronous)
def text_to_speech(text, language):
    speech_key = "2d8ecb53901f475684918912bb47172e"  # Replace with your Azure Speech API key
    service_region = "eastus"  # Replace with your Azure Speech service region

    # Set up speech configuration for the specific language
    speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=service_region)
    speech_config.speech_synthesis_language = language  # Set the language for speech synthesis
    audio_config = speechsdk.audio.AudioOutputConfig(use_default_speaker=True)

    # Create a speech synthesizer
    synthesizer = speechsdk.SpeechSynthesizer(speech_config=speech_config, audio_config=audio_config)

    # Convert the text to speech synchronously
    synthesizer.speak_text(text)  # This ensures speech occurs one after another, waiting for one to finish

# Integrated process: Translate and then Speak for multiple languages
def translate_and_speak(prediction, languages):
    # Map languages to Azure's speech synthesis language codes
    language_map = {
        'es': 'es-ES',  # Spanish
        'fr': 'fr-FR',  # French
        'te': 'te-IN',  # Telugu
        'hi': 'hi-IN',  # Hindi
        'de': 'de-DE' ,  # German
        'en': 'en-US'  # American English
    }

    # Translate the prediction result
    translations = translate_text(prediction, languages)

    # Output the original prediction and translated predictions
    print(f"Original Prediction: {prediction}")
    for lang, translated_text in translations.items():
        print(f"Translated Prediction in {lang.upper()}: {translated_text}")
        
        # Convert the translated text to speech
        text_to_speech(translated_text, language_map[lang])

# Example usage
prediction_result = "Apple Scab detected on the plant."
languages = ['en', 'es', 'fr', 'te', 'hi', 'de']  # Spanish, French, Telugu, Hindi, German
translate_and_speak(prediction_result, languages)
# Out:
# Original Prediction: Apple Scab detected on the plant.
# Translated Prediction in EN: Apple Scab detected on the plant.
# Translated Prediction in ES: Se ha detectado sarna de manzana en la planta.
# Translated Prediction in FR: Tavelure du pommier détectée sur la plante.
# Translated Prediction in TE: ప్లాంట్ పై ఆపిల్ స్కాబ్ ను గుర్తించారు.
# Translated Prediction in HI: पौधे पर एप्पल स्कैब का पता चला।
# Translated Prediction in DE: Apfelschorf an der Pflanze nachgewiesen.

# %%
import requests
import json
import uuid
import azure.cognitiveservices.speech as speechsdk

# Set up Azure services credentials
PREDICTION_KEY = "670ab71352cc48489a92fe5842413ff8"
PREDICTION_ENDPOINT = "https://smartplantassistant-prediction.cognitiveservices.azure.com/"
TRANSLATOR_KEY = 'd71d5ad9793c494ba91af058942f73df'  # Replace with your Azure Translator subscription key
TRANSLATOR_ENDPOINT = 'https://api.cognitive.microsofttranslator.com/'
SPEECH_KEY = "2d8ecb53901f475684918912bb47172e"  # Replace with your Azure Speech API key
SPEECH_REGION = "eastus"  # Replace with your Azure Speech service region

# Function to classify the plant image
def classify_image(image_path):
    project_id = "22f675aa-ab23-4e05-afdc-14b9d657e371"
    publish_iteration_name = "Iteration2"
    
    with open(image_path, "rb") as image_file:
        image_data = image_file.read()

    headers = {
        'Prediction-Key': PREDICTION_KEY,
        'Content-Type': 'application/octet-stream'
    }
    url = f"{PREDICTION_ENDPOINT}customvision/v3.0/Prediction/{project_id}/classify/iterations/{publish_iteration_name}/image"
    
    response = requests.post(url, headers=headers, data=image_data)
    result = response.json()
    return result

# Function to translate text using Azure Translator API
def translate_text(text, target_languages):
    path = '/translate?api-version=3.0'
    params = f'&to={",".join(target_languages)}'
    constructed_url = TRANSLATOR_ENDPOINT + path + params

    headers = {
        'Ocp-Apim-Subscription-Key': TRANSLATOR_KEY,
        'Ocp-Apim-Subscription-Region': "eastus",  # Replace with your resource's region
        'Content-type': 'application/json',
        'X-ClientTraceId': str(uuid.uuid4())
    }

    body = [{'text': text}]
    response = requests.post(constructed_url, headers=headers, json=body)
    result = response.json()
    
    translations = {translation['to']: translation['text'] for translation in result[0]['translations']}
    return translations

# Function to convert text to speech using Azure Speech Service
def text_to_speech(text, language):
    speech_config = speechsdk.SpeechConfig(subscription=SPEECH_KEY, region=SPEECH_REGION)
    speech_config.speech_synthesis_language = language
    audio_config = speechsdk.audio.AudioOutputConfig(use_default_speaker=True)

    synthesizer = speechsdk.SpeechSynthesizer(speech_config=speech_config, audio_config=audio_config)
    synthesizer.speak_text(text)

# Integrated process: Classify, Translate, and Speak
def process_plant_image(image_path):
    # Classify the plant image
    result = classify_image(image_path)
    prediction_result = result.get('predictions', [{}])[0].get('tagName', 'Unknown disease detected.')

    # Specify languages to translate to
    languages = ['en', 'es', 'fr', 'te', 'hi', 'de']  # Add more languages as needed
    translations = translate_text(prediction_result, languages)

    # Output the original prediction and translated predictions
    print(f"Original Prediction: {prediction_result}")
    for lang, translated_text in translations.items():
        print(f"Translated Prediction in {lang.upper()}: {translated_text}")
        text_to_speech(translated_text, lang)

# Example usage
image_path = r"C:\Users\ACER\Downloads\plantvillage dataset\color\Apple___Apple_scab\0a769a71-052a-4f19-a4d8-b0f0cb75541c___FREC_Scab 3165.JPG"  # Use raw string
process_plant_image(image_path)
